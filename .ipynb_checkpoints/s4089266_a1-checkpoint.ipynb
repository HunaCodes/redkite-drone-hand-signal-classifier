# %% [markdown]
# <h1>INITIALISATION</h1>

# %% [markdown]
# **IMPORTANT DECISION**
# - A fixed random seed = 42 will be used for Python, NumPy and Pytorch.
# - Randomness is involved in multiple stages of a Deep Learning workflow (datasplitting, weight updates etc.)
# - Using a fixed seed ensures consistency and reproducibillity of the pipeline

# %%
from pathlib import Path
from PIL import Image

import random
import re
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import torch
import torch.nn as nn
import torch.optim as optim
from torchvision import datasets, transforms
from torch.utils.data import DataLoader, Subset
print("Completed imports.")

# Check if there is a GPU available for performance improvement
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f'Using device: {device}')

# Ensuring Reproductibillity
SEED = 42
random.seed(SEED)
np.random.seed(SEED)
torch.manual_seed(SEED)

print(f"Random Seed ({SEED}) has been Sucessfully Set")
# Out:
# Completed imports.
# Using device: cuda
# Random Seed (42) has been Sucessfully Set

# %% [markdown]
# <h1>SETTING UP THE DATAFRAME</h1>

# %%
DATASET_ROOT = Path("../data_resized")
print("Path check: ", DATASET_ROOT.exists())
# Out:
# Path check:  True

# %% [markdown]
# Now we should explicilty give each class a index so it does not unexpectedly change if we were to simply rely on
# directory ordering

# %%
# Define all the 13 different classes 
CLASS_NAMES = [
    "AllClear",
    "HaveCommand",
    "Hover",
    "Land",
    "LandingDirection",
    "MoveAhead",
    "MoveDownward",
    "MoveToLeft",
    "MoveToRight",
    "MoveUpward",
    "NotClear",
    "SlowDown",
    "WaveOff"
]

class_to_index = {name: i for i, name in enumerate(CLASS_NAMES)}
index_to_class = dict(enumerate(CLASS_NAMES))
class_to_index
# Out:
# {'AllClear': 0,
#  'HaveCommand': 1,
#  'Hover': 2,
#  'Land': 3,
#  'LandingDirection': 4,
#  'MoveAhead': 5,
#  'MoveDownward': 6,
#  'MoveToLeft': 7,
#  'MoveToRight': 8,
#  'MoveUpward': 9,
#  'NotClear': 10,
#  'SlowDown': 11,
#  'WaveOff': 12}

# %% [markdown]
# Quickly ensure the classes have been defined according to the data folder:

# %%
success_count = 0
for i, class_name in enumerate(CLASS_NAMES):
    class_path = DATASET_ROOT / class_name

    if class_path.exists():
        print(f"{i}: {class_name} exists!")
        success_count += 1
    else:
        print(f"{i}: {class_name} DOES NOT EXIST! ERROR!")
print("SUCCESS" if success_count == 13 else "ERROR")
# Out:
# 0: AllClear exists!
# 1: HaveCommand exists!
# 2: Hover exists!
# 3: Land exists!
# 4: LandingDirection exists!
# 5: MoveAhead exists!
# 6: MoveDownward exists!
# 7: MoveToLeft exists!
# 8: MoveToRight exists!
# 9: MoveUpward exists!
# 10: NotClear exists!
# 11: SlowDown exists!
# 12: WaveOff exists!
# SUCCESS

# %% [markdown]
# **IMPORTANT DECISION:**
# We will create a Table in which every row represents a single gesture instance.
# - Each row will have **person_id**, **instance_id**, **class_label** and ordered **5 frame paths**
# - Each frame path represents the separate images that will be fed into the CNN
#
# The <i>person_id</i> will be crucial for data splitting to prevent data leakage since we do not want the **same person** to be in both training and validation/test. This can cause the model to learn **person-specific** features rather than generalising to unseen people.
#
# Since each frame column stores the path to the image; Later a custom PyTorch Dataset will use these paths to load the images.

# %%
# Stores instances of a gesture
gesture_samples = []

for class_name in CLASS_NAMES:
    for person_dir in (DATASET_ROOT / class_name).iterdir():
        if not person_dir.is_dir():
            continue
        for instance_dir in person_dir.iterdir():

            frame_paths = sorted(instance_dir.glob("*.png"))
            
            # .DS_SOTRE files --> ignore
            if not instance_dir.is_dir():
                continue
            # Check if any missing or extra images
            if len(frame_paths) != 5:
                print(f"ERROR! {instance_dir} has {len(frame_paths)} frame")
                # Skip over it to prevent any malformed data from entering the dataframe
                continue

            gesture_samples.append({
                "person_id": int(person_dir.name.removeprefix("S")), 
                "instance_id": int(instance_dir.name.removeprefix("Instance")), 
                "class_name": class_name,
                "class_label": class_to_index[class_name],
                "frame_1": frame_paths[0],
                "frame_2": frame_paths[1],
                "frame_3": frame_paths[2],
                "frame_4": frame_paths[3],
                "frame_5": frame_paths[4]
            })
df = pd.DataFrame(gesture_samples)
df
# Out:
#       person_id  instance_id class_name  class_label  \
# 0             3            2   AllClear            0
# 1             3            5   AllClear            0
# 2             3            9   AllClear            0
# 3             3            4   AllClear            0
# 4             3            3   AllClear            0
# ...         ...          ...        ...          ...
# 1054         13            3    WaveOff           12
# 1055         13            8    WaveOff           12
# 1056         13            6    WaveOff           12
# 1057         13            1    WaveOff           12
# 1058         13            7    WaveOff           12
#
#                                                 frame_1  \
# 0     ../data_resized/AllClear/S3/Instance2/S3_allCl...
# 1     ../data_resized/AllClear/S3/Instance5/S3_allCl...
# 2     ../data_resized/AllClear/S3/Instance9/S3_allCl...
# 3     ../data_resized/AllClear/S3/Instance4/S3_allCl...
# ...

# %% [markdown]
# <h1>Exploratory Data Analysis</h1>

# %%
print(f"Total instances: {len(df)}")
print(f"Total frames: {len(df) * 5}")
print(f"Number of people: {df['person_id'].nunique()}")
# Out:
# Total instances: 1059
# Total frames: 5295
# Number of people: 11

# %% [markdown]
# We will also check swiftly for duplicate instances to ensure, no instances have been repeated by accodient when collecting this data. Duplicate instances can end up spanning across splits, which leads to data leakage and model overfitting to these very specific data points.

# %%
duplicates = df.duplicated(subset=["class_name", "person_id", "instance_id"]).sum()
print("Number of Duplicates:", duplicates)
# Out:
# Number of Duplicates: 0

# %% [markdown]
# <h3>1. Class Distribution</h3>

# %% [markdown]
# Checking class imbalance is crucial in this multiclass classification task since class imbalance can cause the model to be biased towards higher majority classes and often ignore minority classes.
#
# This requires appropriate adjustments to a model's weights to ensure minority labels are given approximately equal consideration by the model.

# %%
class_distribution = (df['class_name'].value_counts())

plt.figure(figsize=(8,5))
class_distribution.plot(kind='bar')
plt.title("Class Distribution Graph")
plt.ylabel("Number of samples")
plt.xlabel("Gesture Class")
plt.xticks(rotation=45, ha="right")
plt.tight_layout()
plt.show()

# %% [markdown]
# As can be seen there is **class imbalance** present within the dataframe. MoveDownward and LandingDirection are some of the underepresented classes, while Land is highly represented. This can cause model to be biased  towards classes like Land.
#
# **IMPORTANT CONSIDERATION 1 (Evaluation Metrics):** This suggests the use of **Macro f1-score** over accuracy alone, since a model can simply achieve a good overall performance score by working well only on majority classes. Since Macro f1-score focuses on how well the model performs on minority classes, we get a much more accurate representation of model performance.
#
# **IMPORTANT CONSIDERATION 2 (Splitting Technqiue):** Given resampling is not ideal due to tight deadline, it is more apporpriate to perform splitting in a manner so that each set, train/validation/test, have a similar proportion of these class samples through each set. One solution could be **Stratified Splitting** however this must be done very carefully.

# %% [markdown]
# <h3>2. Person Distribution</h3>

# %%
person_distribution = (df['person_id'].value_counts().sort_index())

plt.figure(figsize=(8,5))
person_distribution.plot(kind='bar')
plt.title("Person Distribution Graph")
plt.ylabel("Number of Instances")
plt.xlabel("Participants")
plt.xticks(rotation=45, ha="right")
plt.tight_layout()
plt.show()

person_and_classes = pd.crosstab(df['person_id'], df['class_name'])
person_and_classes = person_and_classes.reindex(columns=CLASS_NAMES, fill_value=0)
person_and_classes
# Out:
# class_name  AllClear  HaveCommand  Hover  Land  LandingDirection  MoveAhead  \
# person_id
# 1                  8            9      9    17                 7         10
# 3                  9           10      0     0                 0         10
# 4                  7            7     13    17                 7          6
# 5                  6            5     16    17                 4          8
# 6                  9            5     13    16                 5         10
# 9                 10            9      0     0                 0         10
# 11                 9            7      9    19                 9          8
# 12                 8            7     11    18                 8         10
# 13                 4            9     11    18                 8          9
# 14                10            8      0     0                 0          8
# 15                 7            9      0     0                 0         10
#
# ...

# %% [markdown]
# Observing the results, we clearly see that various participants have performed multiple gesture instances. As mentioned previously, this is why it is very important to ensure:
#
# **IMPORTANT CONSIDERATION 1:** **Group Splitting** in which a specifc participant cannot appear in both training/testing set, and only one. This prevents data leakage and improve generlisational abillity to unseen data rather than learning person-specific features.
#
# **IMPORTANT CONSIDERATION 2 (Stratification and Group-Splitting Trade-off):** While we need to perserve class proportions across our splits, we must also ensure that data from the same <i>person_id</i> stays together in one split. Standard Satratification assumes each row is independent and so is blind to the fact that splitting must done through person_id. Hence when splitting, it **MUST** be ensured that not only do we try our best to perserve class proportions, but more strictly, samples from the same pariticpants cannot end up in different splits.

# %% [markdown]
# <h3>3. Frame Integrity Check</h3>

# %%
frames = ["frame_1", "frame_2", "frame_3", "frame_4", "frame_5"]

frame_sizes = []
frame_modes = []
corrputed_frames = []

for frame in frames:
    for frame_path in df[frame]:

        try:
            with Image.open(frame_path) as img: 
                frame_sizes.append(img.size) 
                frame_modes.append(img.mode) 
                img.verify()
        except Exception as e:
            corrupted_frames.append((f"{frame_path}: {str(e)}"))

# If there is more than one unique element in the set, then we have some data inconsistencies
print("Image Sizes:", set(frame_sizes))
print("Image Modes:", set(frame_modes))
print("No Corrupt Images" if len(corrputed_frames) == 0 else "There are Corrupt Images")
# Out:
# Image Sizes: {(512, 512)}
# Image Modes: {'RGB'}
# No Corrupt Images

# %% [markdown]
# The above check was done to ensure that all images had the same image size, and the same modes. In additon, as part of the PIL library, we use **.verify()** to confirm no image is broken or corrputed which can lead to training failure.
#
# Ensuring Image size and mode is essential to ensure **data consistency** because deep learning models expect uniform data and predictable mathematical inputs, otherwise it can distort the models training.

# %% [markdown]
# <h3>Visualise the "Video" (5 Frames in Motion)</h3>

# %%
fig, axes = plt.subplots(13, 5, figsize=(12, 25))

for i, class_name in enumerate(CLASS_NAMES):
    sample = df[df["class_name"] == class_name].sample(1).iloc[0]

    for j, frame in enumerate(frames):
        axes[i, j].imshow(Image.open(sample[frame]))
        axes[i, j].set_xticks([])
        axes[i, j].set_yticks([])

    axes[i, 0].set_ylabel(class_name)
plt.tight_layout()
plt.show()

# %% [markdown]
# Observing these gesture samples, there are obvious variations in **backbround** and **people**, which can produce a risk. The CNN could potentially rely on the background, scenery and appearance instead of the gesture itself. This will be a even bigger issue assumming specifc people or background enviornments occur more often with particular gestures.
#
# **IMPORTANT CONSIDERATION:** During preprocessing, to tackle this potential issue, small random brightness/contrast changes can be applied during training. This reduces the models reliance on bankground, appearence, clothing etc. while leaving the gesture itself unchanged, thus encouraging the model to learn this consistent arm and body movements.

# %% [markdown]
# <h1>Data Splitting</h1>
